# %%
import pandas as pd
df=pd.read_csv("epl_matches_train.csv")

# %%
import pandas as pd
dftst=pd.read_csv("epl_matches_test.csv")

# %%
teams=pd.read_csv("epl_teams.csv")

# %%
teams=teams.drop(['date'],axis=1)

# %%
dftst=dftst.fillna(dftst.mean())

# %%
import numpy as np
dftst['result']=np.nan
dftst['date']=pd.to_datetime(dftst['date'])
dftst['Year']=dftst['date'].dt.year
dftst['Hour']=(dftst['date'].dt.hour).astype(str)
dftst['Month']=dftst['date'].dt.month
dftst['Day']=dftst['date'].dt.day

# %%
import numpy as np
df['result']=np.nan
df['date']=pd.to_datetime(df['date'])
df['Year']=df['date'].dt.year
df['Hour']=(df['date'].dt.hour).astype(str)
df['Month']=df['date'].dt.month
df['Day']=df['date'].dt.day

# %%
for index, row in df.iterrows():
    if(row['home_team_goal']>row['away_team_goal']):
        df.loc[index,['result']]="win"
    elif(row['home_team_goal']<row['away_team_goal']):
        df.loc[index,['result']]="lose"
    elif(row['home_team_goal']==row['away_team_goal']):
        df.loc[index,['result']]="draw"

# %%
dftt=dftst.loc[:, ~dftst.columns.isin(['on_target_shot_home_team','on_target_shot_away_team','off_target_shot_home_team','off_target_shot_away_team','foul_home_team','foul_away_team','yellow_card_home_team','yellow_card_away_team','red_card_home_team','red_card_away_team'
,'crosses_home_team','crosses_away_team','corner_home_team','corner_away_team','possession_home_team','possession_away_team','season', 'stage','date','match_id','Hour','home_team_goal','away_team_goal'])]
# dftst2=dftst2.dropna()

# %%
df.head()
# Out:
#       season  stage       date  match_id  home_team_id  away_team_id  \
# 0  2008/2009      1 2008-08-17     49337         10260         10261
# 1  2008/2009      1 2008-08-16     38136          9825          8659
# 2  2008/2009      1 2008-08-16     43276          8472          8650
# 3  2008/2009      1 2008-08-16     40671          8654          8528
# 4  2008/2009      1 2008-08-17     34633         10252          8456
#
#    home_player_X1  home_player_X2  home_player_X3  home_player_X4  ...  \
# 0               1               2               4               6  ...
# 1               1               2               4               6  ...
# 2               1               2               4               6  ...
# 3               1               2               4               6  ...
# 4               1               2               4               6  ...
#
#    corner_away_team  possession_home_team  possession_away_team  \
# ...

# %%
new_df=pd.get_dummies(new_df)

# %%
df2=new_df2.copy()

# %%
df=df.fillna(df.mean())
# Out:
# C:\Users\dmsss\anaconda3\envs\env2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.

# %%
dftst2=dftt.copy()

# %%
dftst2=dftst2.drop(['result','Year'],axis=1)

# %%
df_ytr=pd.get_dummies(df_ytr)
df_yte=pd.get_dummies(df_yte)
df_Xtr=pd.get_dummies(df_Xtr)
df_Xte=pd.get_dummies(df_Xte)

# %%
dftrain=df2[(df2.Year==2008)|(df2.Year==2009)|(df2.Year==2010)|(df2.Year==2011)|(df2.Year==2012)|(df2.Year==2013)|(df2.Year==2014)|(df2.Year==2015)]

# %%
df_Xtr.to_csv("df_Xtrhead.csv")

# %%
df_Xtr=dftrain.loc[:,~dftrain.columns.isin(['result'])]
df_ytr=dftrain.loc[:,['result']]
df_Xte=dftest.loc[:,~dftest.columns.isin(['result'])]
df_yte=dftest.loc[:,['result']]
df_Xtr=df_Xtr.drop(['Year'], axis=1)
df_Xte=df_Xte.drop(['Year'], axis=1)

# %%
>>> from sklearn.naive_bayes import CategoricalNB
>>> clf3 = CategoricalNB()
clf3.fit(df_Xtr,df_ytr);
# Out:
# C:\Users\dmsss\anaconda3\envs\env2\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
dfnew2=df.iloc[:,0:2]

# %%
dfneww=pd.concat([dfnew,dfnew2])

# %%
# y_testarr=df_yte.to_numpy()
pred=clf.predict(dftst2)
# from sklearn.metrics import accuracy_score
# accuracy_score(df_yte,pred)

# %%
dftst['result']=pred

# %%
dftst.head()
# Out:
#       season  stage       date  match_id  home_team_id  away_team_id  \
# 0  2015/2016      1 2015-08-09     48994          9825          8654
# 1  2015/2016      1 2015-08-08     54777          8678         10252
# 2  2015/2016      1 2015-08-08     31434          8455         10003
# 3  2015/2016      1 2015-08-08     56248          8668          9817
# 4  2015/2016      1 2015-08-08     44311          8197          8472
#
#    home_player_X1  home_player_X2  home_player_X3  home_player_X4  ...  \
# 0               1               2               4               6  ...
# 1               1               2               4               6  ...
# 2               1               2               4               6  ...
# 3               1               2               4               6  ...
# 4               1               3               5               7  ...
#
#    away_player_11  result  Year  Hour  Month  Day  HmGoals  Hmassists  \
# ...

# %%
dftst.to_csv("solution.csv")

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier(random_state=100)
modeldt=dc.fit(df_Xtr,df_ytr)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(df_Xtr,df_ytr)
# Out:
# C:\Users\dmsss\anaconda3\envs\env2\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier()

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2
import keras as kf

# %%
modeldp = Sequential()
modeldp.add(Dense(1024, activation='relu'))
modeldp.add(Dense(3,activation='softmax'))
modeldp.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
earlystop=EarlyStopping(monitor='val_acc',min_delta=0,
                        patience=7,
                        verbose=1,
                        restore_best_weights=True)
callbacks=[earlystop]
#Training the model  
modeldp.fit(df_Xtr,df_ytr,
          batch_size=150,  
          epochs=150,  
          callbacks=callbacks,
          validation_data=(df_Xte,df_yte),  
          shuffle=True)
# Out:
# Epoch 1/150
# 14/14 [==============================] - 11s 211ms/step - loss: 7797.6399 - accuracy: 0.3160 - val_loss: 7832.8140 - val_accuracy: 0.3737
# Epoch 2/150
# 14/14 [==============================] - ETA: 0s - loss: 2628.0326 - accuracy: 0.4057
# C:\Users\dmsss\anaconda3\envs\env2\lib\site-packages\keras\callbacks\callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 14/14 [==============================] - 0s 34ms/step - loss: 2601.8065 - accuracy: 0.4047 - val_loss: 4552.6045 - val_accuracy: 0.4053
# Epoch 3/150
# 14/14 [==============================] - 0s 32ms/step - loss: 1412.3782 - accuracy: 0.4426 - val_loss: 4455.6934 - val_accuracy: 0.3842
# Epoch 4/150
# 14/14 [==============================] - 0s 37ms/step - loss: 1294.0380 - accuracy: 0.4124 - val_loss: 3560.2727 - val_accuracy: 0.3509
# ...

# %%
score = modeldp.evaluate(df_Xte,df_yte, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 4431.0869140625
# Test accuracy: 0.41578948497772217

# %%
goals=pd.read_csv("epl_goals.csv")

# %%
dftst.head()
# Out:
#       season  stage       date  match_id  home_team_id  away_team_id  \
# 0  2015/2016      1 2015-08-09     48994          9825          8654
# 1  2015/2016      1 2015-08-08     54777          8678         10252
# 2  2015/2016      1 2015-08-08     31434          8455         10003
# 3  2015/2016      1 2015-08-08     56248          8668          9817
# 4  2015/2016      1 2015-08-08     44311          8197          8472
#
#    home_player_X1  home_player_X2  home_player_X3  home_player_X4  ...  \
# 0               1               2               4               6  ...
# 1               1               2               4               6  ...
# 2               1               2               4               6  ...
# 3               1               2               4               6  ...
# 4               1               3               5               7  ...
#
#    away_player_7  away_player_8  away_player_9  away_player_10  \
# ...

# %%
df["HmGoals"]=np.nan
df["Hmassists"]=np.nan

df["awGoals"]=np.nan
df["awassists"]=np.nan

# %%
df3st=dftst.iloc[:,50:72]

# %%
df3st.head()
# Out:
#    home_player_1  home_player_2  home_player_3  home_player_4  home_player_5  \
# 0          30859        26154.0          35606          46539          38521
# 1          30974        35515.0          24625         156013          68237
# 2         170323        31306.0          23783          30627          72541
# 3          31465        77690.0         263653          23268         316688
# 4          37770        67850.0          38899          23571         139671
#
#    home_player_6  home_player_7  home_player_8  home_player_9  home_player_10  \
# 0         159594          37436        75489.0          36378          196386
# 1         155913          46810        23629.0          24381          185236
# 2         115067          30613        94086.0         128864          107417
# 3          23782         101192        26151.0         160713          215384
# 4         103419         173317       214570.0         278343           20694
#
# ...

# %%
for index,rowval in df3st.iterrows():
    counthm=1
    countaw=0
    valgls=0
    valass=0
    boo=0
    for col in rowval:
        print(col)
        if(counthm!=11):    
            plid=int(col)
            a=(goals.loc[goals['player1_id.1']==plid,'goals']).to_numpy()
            if(a.size!=0):    
                valgls=valgls+int(((goals.loc[goals['player1_id.1']==plid,'goals']).to_numpy())[0])
            b=(goals.loc[goals['player2_id.1']==plid,'assists']).to_numpy()
            if(b.size!=0):    
                valass=valass+int(((goals.loc[goals['player2_id.1']==plid,'assists']).to_numpy())[0])
            counthm=counthm+1
        else:
            if(boo==0):   
                boo=1
                print(valgls)
                dftst.loc[index,'HmGoals']=valgls
                dftst.loc[index,'Hmassists']=valass
                counthm=1
                valgls=0
                valass=0
            else:
                print(valgls)
                dftst.loc[index,'awGoals']=valgls
                dftst.loc[index,'awassists']=valass
                counthm=1
                valgls=0
                valass=0
# Out:
# 30859.0
# 26154.0
# 35606.0
# 46539.0
# 38521.0
# 159594.0
# 37436.0
# 75489.0
# 36378.0
# 196386.0
# 46469.0
# 85
# 169756.0
# 109897.0
# 35110.0
# 49543.0
# 155782.0
# 37169.0
# 575789.0
# 148302.0
# 25496.0
# 18506.0
# 192899.0
# 38
# 30974.0
# 35515.0
# 24625.0
# 156013.0
# 68237.0
# 155913.0
# 46810.0
# 23629.0
# 24381.0
# 185236.0
# 184321.0
# 9
# 69650.0
# 183500.0
# 24208.0
# 161414.0
# 473853.0
# 261313.0
# 179410.0
# 182223.0
# 23991.0
# 154280.0
# 23264.0
# 35
# 170323.0
# 31306.0
# 23783.0
# 30627.0
# 72541.0
# 115067.0
# 30613.0
# 94086.0
# 128864.0
# 107417.0
# 19243.0
# 159
# 30973.0
# 111800.0
# 155050.0
# 24948.0
# 102356.0
# 127130.0
# 144996.0
# 95955.0
# 157729.0
# 52563.0
# 26344.0
# 50
# 31465.0
# 77690.0
# 263653.0
# 23268.0
# 316688.0
# 23782.0
# 101192.0
# 26151.0
# 160713.0
# 215384.0
# 181276.0
# 98
# 30455.0
# 213809.0
# 41927.0
# 40548.0
# 35712.0
# 41365.0
# 30966.0
# 24915.0
# 37411.0
# 71724.0
# 72436.0
# 7
# 37770.0
# 67850.0
# 38899.0
# 23571.0
# ...

# %%
teams=teams.fillna(teams.mean())

# %%
teams=teams.rename(columns={"team_id":"home_team_id"})

# %%
teamsbck=teams.copy()

# %%
new_df.head()
# Out:
#    home_team_id  buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0          9825                66              Balanced             37.588235
# 1          9825                66              Balanced             37.588235
# 2          9825                66              Balanced             37.588235
# 3          9825                66              Balanced             37.588235
# 4          9825                66              Balanced             37.588235
#
#   buildUpPlayDribblingClass  buildUpPlayPassing buildUpPlayPassingClass  \
# 0                    Little                  30                   Short
# 1                    Little                  30                   Short
# 2                    Little                  30                   Short
# 3                    Little                  30                   Short
# 4                    Little                  30                   Short
#
#   buildUpPlayPositioningClass  chanceCreationPassing  \
# ...

# %%
new_df = pd.merge(teams,df, on="home_team_id")

# %%
players=pd.read_csv("epl_players.csv")

# %%
players.head()
# Out:
#    player_id  finishing  heading_accuracy  short_passing  volleys  dribbling  \
# 0     155782       53.0              58.0           71.0     40.0       73.0
# 1     155782       53.0              58.0           71.0     32.0       73.0
# 2     155782       52.0              57.0           70.0     29.0       71.0
# 3     155782       51.0              57.0           70.0     29.0       71.0
# 4     155782       51.0              57.0           70.0     29.0       71.0
#
#    free_kick_accuracy  long_passing  sprint_speed  balance  shot_power  \
# 0                69.0          68.0          78.0     90.0        71.0
# 1                69.0          68.0          78.0     90.0        71.0
# 2                69.0          68.0          78.0     90.0        71.0
# 3                69.0          68.0          78.0     90.0        71.0
# 4                69.0          68.0          78.0     90.0        71.0
#
#    stamina  interceptions  penalties  gk_diving  gk_handling  gk_kicking  \
# ...

# %%
players['goals']=np.nan
players['assists']=np.nan

# %%
for index,rowval in players.iterrows():
    a=(goals.loc[goals['player1_id.1']==rowval['player_id'],'goals']).to_numpy()
    if(a.size!=0):
        rowval['goals']=int(((goals.loc[goals['player1_id.1']==rowval['player_id'],'goals']).to_numpy())[0])
    b=(goals.loc[goals['player2_id.1']==rowval['player_id'],'assists']).to_numpy()
    if(b.size!=0):
        rowval['assists']=int(((goals.loc[goals['player2_id.1']==rowval['player_id'],'assists']).to_numpy())[0])

# %%
players.head()
# Out:
#    player_id  finishing  heading_accuracy  short_passing  volleys  dribbling  \
# 0     155782       53.0              58.0           71.0     40.0       73.0
# 1     155782       53.0              58.0           71.0     32.0       73.0
# 2     155782       52.0              57.0           70.0     29.0       71.0
# 3     155782       51.0              57.0           70.0     29.0       71.0
# 4     155782       51.0              57.0           70.0     29.0       71.0
#
#    free_kick_accuracy  long_passing  sprint_speed  balance  ...  stamina  \
# 0                69.0          68.0          78.0     90.0  ...     79.0
# 1                69.0          68.0          78.0     90.0  ...     79.0
# 2                69.0          68.0          78.0     90.0  ...     79.0
# 3                69.0          68.0          78.0     90.0  ...     79.0
# 4                69.0          68.0          78.0     90.0  ...     79.0
#
# ...

# %%
players2=players.groupby('player_id').sum()

# %%
players2.head()
# Out:
#            finishing  heading_accuracy  short_passing  volleys  dribbling  \
# player_id
# 2802          1598.0            1226.0         1576.0   1502.0     1828.0
# 3512           749.0             548.0          869.0    876.0      944.0
# 3520          1909.0            1203.0         2026.0   1891.0     2099.0
# 8922          1943.0            1892.0         1451.0   1737.0     1732.0
# 8985          1462.0            1852.0         1819.0   1713.0     1416.0
#
#            free_kick_accuracy  long_passing  sprint_speed  balance  \
# player_id
# 2802                   1665.0        1531.0        1755.0   1671.0
# 3512                    804.0         837.0         970.0    833.0
# 3520                   1857.0        1900.0        1955.0   2040.0
# 8922                   1681.0        1023.0        1804.0   1301.0
# 8985                   1805.0        1739.0        1635.0   1819.0
#
#            shot_power  stamina  interceptions  penalties  gk_diving  \
# player_id
# ...

# %%
sortedply=players2.sort_values(['finishing', 'heading_accuracy','short_passing','volleys','dribbling','free_kick_accuracy','long_passing','sprint_speed','balance','shot_power','stamina','interceptions','penalties','gk_diving','gk_handling','gk_kicking','gk_positioning','gk_reflexes','goals','assists'], ascending=False)

# %%
sortedply.head()
# Out:
#            finishing  heading_accuracy  short_passing  volleys  dribbling  \
# player_id
# 108808        3761.0            3318.0         3396.0   3697.0     3847.0
# 37799         3592.0            3047.0         3228.0   3494.0     3527.0
# 47394         3499.0            1958.0         3836.0   3608.0     4294.0
# 194165        3449.0            3189.0         3119.0   2932.0     3212.0
# 49825         3430.0            3349.0         3035.0   3454.0     3305.0
#
#            free_kick_accuracy  long_passing  sprint_speed  balance  \
# player_id
# 108808                 3502.0        2484.0        3722.0   2497.0
# 37799                  2633.0        2477.0        4332.0   3922.0
# 47394                  3695.0        3375.0        3734.0   3794.0
# 194165                 2834.0        2401.0        3385.0   3137.0
# 49825                  2166.0        2390.0        3398.0   2439.0
#
#            shot_power  stamina  interceptions  penalties  gk_diving  \
# player_id
# ...

# %%
top_players=sortedply.head(10)

# %%
bottom_players=sortedply.tail(10)

# %%
top_players.head(11)

# %%
top_players.to_csv("top_players.csv")

# %%
bottom_players.to_csv("bottom_players.csv")
